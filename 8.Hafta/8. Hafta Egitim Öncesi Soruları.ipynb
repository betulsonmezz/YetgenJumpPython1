# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
def urunKaydet():
    urunAdi=input("ürün adi giriniz : ")
    urunFiyati=int(input("ürün fiyati giriniz : "))

    with open("urunler.txt", "w", encoding="utf-8") as file:
        file.write("urunAdi\n"  "urunFiyati\n" )
        
    print("Ürün kaydedildi.")
urunKaydet()
# Out:
# Ürün kaydedildi.

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
def yer_degistime():
    eski_kelime = input("Değiştirilecek kelimeyi giriniz: ")
    yeni_kelime = input("Yeni Kelimenizi giriniz: ")
    with open("urunler.txt", "r") as file:
        lines = f.readlines()
    with open("urunler", "w" , encoding="utf-8") as file:
        for satır in satırlar:
            yeni_satır = satır.replace(eski_kelime, yeni_kelime)
            file.write(yeni_satır)
    print("kelime değiştirildi.")

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
class Vehicle:
    def __init__(self, model, yil, agirlik):
        self.model = model
        self.yil = yil
        self.agirlik = agirlik
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 25
#      22         print("araba durdu...")
#      24 Arabam = Bus("Volvo", "XC60", 2022, 2000,)
# ---> 25 print(Arabam.bilgiGetir())
#      26 Arabam.arac()
#      27 Arabam.durma()
#
# Cell In[18], line 16, in Bus.bilgiGetir(self)
#      15 def bilgiGetir(self):
# ---> 16     return f"{super().bilgiGetir()} yolcu kapasitesi {self.kapasite}"
#
# AttributeError: 'super' object has no attribute 'bilgiGetir'
